# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruven-god/Ineuron_projects/blob/main/Stats_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy.stats as sts
from scipy.stats import norm
import math
import numpy as np

# null_hypothesis = raw cornstarch has no effect
# alternate hypothesis = raw cornstarch has effect

pop_mean = 100
std = 15
n = 36
sample_mean = 108

alpha = 0.05

std_error = std/n**0.5
print(f"SE: {std_error}")
Z = (sample_mean-pop_mean)/std_error
print(f"Z_score: {Z}")

# by looking at z- table and p-value associated with 3.20 is 0.9993 
# The probability of having value less than 108 is 0.9993 and more than or equals to 108 is (1-0.9993)=0.0007.
# Since the probability of having mean glucose level more than or equals to 108  is 0.0007 which is  less than 0.05 
#so we will reject the Null hypothesis i.e. there is raw cornstarch effect

# %%
n1 = 100
n2 = 100
R1 = 0.52           
D1 = 0.48         
R2 = 0.47           
D2 = 0.53          

mu = R1 - R2
print(f"mu: {mu}")
std = np.sqrt(((R1 * D1 ) / n1) + ((R2 * D2) /n2))
print(f"std: {std}")
 
#This is equivalent to finding the probability that R1 - R2 < 0. 
x = 0 

Z_final = ( x - mu)/std
print(f"Z_final : {Z_final}")


print("Probab of z-score being -0.7082 is = 0.24")

#Therefore, the probability that the survey will show a greater percentage of Republican voters in the second state than in the first state is 0.24

# %%
x = 1100
pop_mean = 1026
std = 209

z = (x-pop_mean)/std
print("Z-score is ",z)

print("Score is in range of {},{}".format(pop_mean-std,pop_mean+std))
